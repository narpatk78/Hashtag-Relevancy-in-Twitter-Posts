# %% [markdown]
# <center>
#
# # Data Preprocessing and Cleaning
#
# </center>

# %% [markdown]
# #### importing libraries

# %%
# importing libraries
import pandas as pd
import re
from langdetect import detect
from transformers import BertTokenizer
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# viewing the data
data = pd.read_csv("Twitter Data (Original).csv")
data.head()
# Out:
#          id           created  favoriteCount isRetweet  retweetCount  \
# 0  8.83E+17  07-06-2017 17:17            0.0     False           0.0
# 1  8.83E+17  07-06-2017 17:17            0.0      True          43.0
# 2  8.83E+17  07-06-2017 17:17            0.0     False           0.0
# 3  8.83E+17  07-06-2017 17:16            0.0     False           0.0
# 4  8.83E+17  07-06-2017 17:16            0.0      True           1.0
#
#   retweeted       screenName  \
# 0     False       infocaptor
# 1     False           candle
# 2     False        AwesomeEK
# 3     False    conney_island
# 4     False  blockchainreach
#
#                                                 text tashtag Unnamed: 9
# 0  #API - #Data #Sourcing\r\nhttps://t.co/5YO2s1D...   #data        NaN
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...   #data        NaN
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...   #data        NaN
# 3  Cambiar la rutina matutina ayuda a terminar co...   #data        NaN
# 4  RT @simonnash2017: These are the #Top20 #BigDa...   #data        NaN

# %%
# dropping columns which are not required
data = data.drop(['id', 'created', 'favoriteCount', 'isRetweet', 'retweetCount', 'retweeted', 'screenName', 'tashtag', 'Unnamed: 9'], axis = 1)

# %%
# checking for null values present in the 'text' column
print("Number of null entries in the 'text' column: ", data['text'].isnull().sum(), '\n')

# reoving the null values
print('Removing null values from the column.......')
data = data.dropna(subset=['text'])
print("Number of null entries in the 'text' column: ", data['text'].isnull().sum())
data['text'].isnull().sum()
# Out:
# Number of null entries in the 'text' column:  6
#
# Removing null values from the column.......
# Number of null entries in the 'text' column:  0
# 0

# %% [markdown]
# #### removing URLs from the posts

# %%
# removing the urls
def remove_urls(text):
    '''function to remove urls from the posts'''
    return re.sub(r'http\S+', '', text)

# %%
# creating a column which gives the posts without the urls
data['removed_https'] = data['text'].apply(remove_urls)
data.head()
# Out:
#                                                 text  \
# 0  #API - #Data #Sourcing\r\nhttps://t.co/5YO2s1D...
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                        removed_https
# 0                        #API - #Data #Sourcing\r\n
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...

# %% [markdown]
# #### removing retweets from the posts

# %%
# removing retweets and the account whose post was retweeted
def remove_retweets(text):
    '''function to remove retweets and the account whose post was retweeted'''
    # Define a regular expression pattern to match retweets
    pattern = r'^RT @\w+:'
    return re.sub(pattern, '', text)

# %%
# creating a column to get the posts with no retweets mentioned
data['removed_retweets'] = data['removed_https'].apply(remove_retweets)
data.head()
# Out:
#                                                 text  \
# 0  #API - #Data #Sourcing\r\nhttps://t.co/5YO2s1D...
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                        removed_https  \
# 0                        #API - #Data #Sourcing\r\n
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                     removed_retweets
# 0                        #API - #Data #Sourcing\r\n
# 1   Before Powerpoint @NASA 1961\r\n\r\n#AI #star...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4   These are the #Top20 #BigData &amp; #AI on #t...

# %% [markdown]
# #### extracting hashtags

# %%
# Extract hashtags
data['Hashtags'] = data['removed_retweets'].apply(lambda x: ' '.join(re.findall(r'#\w+', x)))
# Remove hashtags from text
data['text_without_hashtags'] = data['removed_retweets'].apply(lambda x: re.sub(r'#', '', x))
data.head()
# Out:
#                                                 text  \
# 0  #API - #Data #Sourcing\r\nhttps://t.co/5YO2s1D...
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                        removed_https  \
# 0                        #API - #Data #Sourcing\r\n
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                     removed_retweets  \
# 0                        #API - #Data #Sourcing\r\n
# 1   Before Powerpoint @NASA 1961\r\n\r\n#AI #star...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4   These are the #Top20 #BigData &amp; #AI on #t...
#
#                                             Hashtags  \
# 0                               #API #Data #Sourcing
# 1  #AI #startup #tech #IoT #data #stocks #code #g...
# 2  #Predicted #Marketing #Trends #Mobile #AR #VR ...
# 3                                              #Data
# 4  #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
#
#                                text_without_hashtags
# 0                           API - Data Sourcing\r\n
# 1   Before Powerpoint @NASA 1961\r\n\r\nAI startu...
# 2  Looking Ahead: 17 Predicted Marketing Trends I...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4   These are the Top20 BigData &amp; AI on twitt...

# %% [markdown]
# #### extracting mentions

# %%
# extracting mentioned accounts in the posts
def extract_mentions(text):
    '''function to extract mentioned accounts in the posts'''
    # Use regular expressions to find mentions
    mentions = re.findall(r'@(\w+)', text)
    # Remove "@" sign from the original text
    cleaned_text = re.sub(r'@', '', text)
    return mentions, cleaned_text

# %%
# Define a function to convert a list into a string
def list_to_string(input_list):
    '''funciton to unlist a list and join them using ','.'''
    return ', '.join(input_list)

# function to remove leading spaces from a sentence
def remove_leading_spaces(text):
    return text.lstrip()

# %%
# creating columns to store the mentioned accounts and text with no mentions
data['Mentioned_Accounts'], data['Text_No_Mentions'] = zip(*data['text_without_hashtags'].apply(extract_mentions))

# Apply the function to a specific column in the DataFrame
data['Mentioned_Accounts'] = data['Mentioned_Accounts'].apply(list_to_string)

# removing lead spaces
data['Text_No_Mentions'] = data['Text_No_Mentions'].apply(remove_leading_spaces)

data.head()
# Out:
#                                                 text  \
# 0  #API - #Data #Sourcing\r\nhttps://t.co/5YO2s1D...
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                        removed_https  \
# 0                        #API - #Data #Sourcing\r\n
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                     removed_retweets  \
# 0                        #API - #Data #Sourcing\r\n
# 1   Before Powerpoint @NASA 1961\r\n\r\n#AI #star...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4   These are the #Top20 #BigData &amp; #AI on #t...
#
#                                             Hashtags  \
# 0                               #API #Data #Sourcing
# 1  #AI #startup #tech #IoT #data #stocks #code #g...
# 2  #Predicted #Marketing #Trends #Mobile #AR #VR ...
# 3                                              #Data
# 4  #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
#
#                                text_without_hashtags Mentioned_Accounts  \
# 0                           API - Data Sourcing\r\n
# 1   Before Powerpoint @NASA 1961\r\n\r\nAI startu...               NASA
# 2  Looking Ahead: 17 Predicted Marketing Trends I...
# 3  Cambiar la rutina matutina ayuda a terminar co...           LANACION
# 4   These are the Top20 BigData &amp; AI on twitt...
#
#                                     Text_No_Mentions
# 0                           API - Data Sourcing\r\n
# 1  Before Powerpoint NASA 1961\r\n\r\nAI startup ...
# 2  Looking Ahead: 17 Predicted Marketing Trends I...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  These are the Top20 BigData &amp; AI on twitte...

# %% [markdown]
# #### detecting the language of the posts

# %%
def detect_language(text):
    '''Function to detect the language of a text'''
    try:
        return detect(text)
    except:
        # If language detection fails, return 'unknown'
        return 'unknown'

# %%
# creating a column for the language detected
data['language'] = data['Text_No_Mentions'].apply(detect_language)
data.head()
# Out:
#                                                 text  \
# 0  #API - #Data #Sourcing\r\nhttps://t.co/5YO2s1D...
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                        removed_https  \
# 0                        #API - #Data #Sourcing\r\n
# 1  RT @PitchCrunch: Before Powerpoint @NASA 1961\...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4  RT @simonnash2017: These are the #Top20 #BigDa...
#
#                                     removed_retweets  \
# 0                        #API - #Data #Sourcing\r\n
# 1   Before Powerpoint @NASA 1961\r\n\r\n#AI #star...
# 2  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 3  Cambiar la rutina matutina ayuda a terminar co...
# 4   These are the #Top20 #BigData &amp; #AI on #t...
#
#                                             Hashtags  \
# 0                               #API #Data #Sourcing
# 1  #AI #startup #tech #IoT #data #stocks #code #g...
# 2  #Predicted #Marketing #Trends #Mobile #AR #VR ...
# 3                                              #Data
# 4  #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
#
#                                text_without_hashtags Mentioned_Accounts  \
# 0                           API - Data Sourcing\r\n
# 1   Before Powerpoint @NASA 1961\r\n\r\nAI startu...               NASA
# 2  Looking Ahead: 17 Predicted Marketing Trends I...
# 3  Cambiar la rutina matutina ayuda a terminar co...           LANACION
# 4   These are the Top20 BigData &amp; AI on twitt...
#
#                                     Text_No_Mentions language
# 0                           API - Data Sourcing\r\n        en
# 1  Before Powerpoint NASA 1961\r\n\r\nAI startup ...       en
# 2  Looking Ahead: 17 Predicted Marketing Trends I...       en
# 3  Cambiar la rutina matutina ayuda a terminar co...       es
# 4  These are the Top20 BigData &amp; AI on twitte...       en

# %%
# filtering for only English posts
english_posts = data[data['language'] == 'en']

# getting the required columns from the dataframe
english_posts1 = english_posts[['text','Text_No_Mentions','Hashtags']]

# %%
# renaming columns
english_posts1.rename(columns = {'text':'Post', 'Text_No_Mentions' : 'Text'}, inplace = True)
# Out:
# C:\Users\Narpat\AppData\Local\Temp\ipykernel_26540\1393960996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_posts1.rename(columns = {'text':'Post', 'Text_No_Mentions' : 'Text'}, inplace = True)

# %% [markdown]
# #### creating csv files for the cleaned data

# %%
# data containing all the columns but with posts in english language
english_posts.to_csv("Twitter Data (English).csv", index=False, encoding="utf-8")

# data containing the required columns and posts in english language
english_posts1.to_csv("Twitter Data (Cleaned).csv", index=False, encoding="utf-8")

# %% [markdown]
# #### preprocessing

# %%
# Initialize an empty list to hold the data
data = []
column_names = None 

# Open the CSV file and read each line
with open("Twitter Data (Cleaned).csv", 'r', encoding='utf-8') as file:
    for line in file:
        # Attempt to split the line into fields
        fields = line.strip().split(',')
        if column_names is None:
            # If column names are not set, use the first row as column names
            column_names = fields
        # Check if the number of fields in the line is as expected (e.g., 3)
        else:
            if len(fields) == 3:
                data.append(fields)
            else:
                # Handle the line with an unexpected number of fields, e.g., skip it
                print(f"Skipped line with {len(fields)} fields: {line}")

# Create a DataFrame from the collected data
tweets = pd.DataFrame(data, columns=column_names)
# Out:
# Skipped line with 1 fields: "#API - #Data #Sourcing
#
# Skipped line with 2 fields: https://t.co/5YO2s1D4vq https://t.co/O9IsY7pqVF","API - Data Sourcing
#
# Skipped line with 2 fields:  ",#API #Data #Sourcing
#
# Skipped line with 1 fields: "RT @PitchCrunch: Before Powerpoint @NASA 1961
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #AI #startup #tech #IoT #data #stocks #code #gamedev #VentureCapital #gaming #Python #bitcoi…","Before Powerpoint NASA 1961
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: AI startup tech IoT data stocks code gamedev VentureCapital gaming Python bitcoi…",#AI #startup #tech #IoT #data #stocks #code #gamedev #VentureCapital #gaming #Python #bitcoi
#
# Skipped line with 5 fields: "RT @MSCloud: Using #Azure, @IOInteractive collects and analyzes telemetry #data from live gameplay. Read: https://t.co/kAJxPFZyec https://t…","Using Azure, IOInteractive collects and analyzes telemetry data from live gameplay. Read:  ",#Azure #data
#
# Skipped line with 5 fields: "When you're building your buyer personas, always remember to back it with #data: https://t.co/EResYD99dv https://t.co/K8q9HGTKpg","When you're building your buyer personas, always remember to back it with data:  ",#data
#
# Skipped line with 1 fields: "Is your organization ready to embark on the road to digitalization? Check out the Biggest Risks of Unreliable #Data
#
# Skipped line with 2 fields: https://t.co/CaiF6vSzqp","Is your organization ready to embark on the road to digitalization? Check out the Biggest Risks of Unreliable Data
#
# Skipped line with 2 fields: ",#Data
#
# Skipped line with 5 fields: "Correct, and our @FamProsperity Index has the comprehensive #data that proves it. @ACUFoundation. #tcot https://t.co/rGwStPEK4j","Correct, and our FamProsperity Index has the comprehensive data that proves it. ACUFoundation. tcot ",#data #tcot
#
# Skipped line with 5 fields: "Yes, you may use this #data - as long as you mention the original source. https://t.co/MP3mAeM57a https://t.co/hGLKGf6NWp","Yes, you may use this data - as long as you mention the original source.  ",#data
#
# Skipped line with 7 fields: "#AI's ability to make sense of #data, even unstructured, is powering improved customer experiences… https://t.co/hRBpwuDKOz","AI's ability to make sense of data, even unstructured, is powering improved customer experiences… ",#AI #data
#
# Skipped line with 5 fields: "Webinar, July 25: Smart #data #catalog that manages and maximizes the value and re-use of data assets. https://t.co/0cfB8TdKlu  #BigData","Webinar, July 25: Smart data catalog that manages and maximizes the value and re-use of data assets.   BigData",#data #catalog #BigData
#
# Skipped line with 2 fields: "Microsoft to lay off 3,000 people as it tries to boost Azure https://t.co/xFj265RkIg via @engadget
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: #cloud
#
# Skipped line with 1 fields: #data
#
# Skipped line with 1 fields: #technews
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: cloud
#
# Skipped line with 1 fields: data
#
# Skipped line with 1 fields: technews
#
# Skipped line with 2 fields: bigdata",#cloud #data #technews #bigdata
#
# Skipped line with 5 fields: "'Regulating the internet giants: The world’s most valuable resource is no longer oil, but #data' https://t.co/kvbxkN0sqX via @TheEconomist","'Regulating the internet giants: The world’s most valuable resource is no longer oil, but data'  via TheEconomist",#data
#
# Skipped line with 1 fields: "binaryloom: RT ThoHeller: Getting Started with #Python for #Data #Analysis. Towards #DataScience. https://t.co/NqoqNQBSLs
#
# Skipped line with 2 fields: #BigData #Analyt…","binaryloom: RT ThoHeller: Getting Started with Python for Data Analysis. Towards DataScience.
#
# Skipped line with 2 fields: BigData Analyt…",#Python #Data #Analysis #DataScience #BigData #Analyt
#
# Skipped line with 1 fields: "If you:
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields:  <U+2705> in #SLC, UT
#
# Skipped line with 1 fields:  <U+2705> Like #data
#
# Skipped line with 1 fields:  <U+2705> Have a penchant for #writing
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: Check out our internship! https://t.co/AZwAPp5lbv @frontanalytics","If you:
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields:  <U+2705> in SLC, UT
#
# Skipped line with 1 fields:  <U+2705> Like data
#
# Skipped line with 1 fields:  <U+2705> Have a penchant for writing
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: Check out our internship!  frontanalytics",#SLC #data #writing
#
# Skipped line with 7 fields: "RT @GlobalCIO: 'To #innovate don't ask customers what they think, you must know what they do. Behavioural #data is key,' says @JoshValman #…","'To innovate don't ask customers what they think, you must know what they do. Behavioural data is key,' says JoshValman …",#innovate #data
#
# Skipped line with 1 fields: "How to Integrate #Data and #Analytics into Every Part of Your Organization | #DigitalTransformation
#
# Skipped line with 2 fields: https://t.co/5DkJfwMax5","How to Integrate Data and Analytics into Every Part of Your Organization | DigitalTransformation
#
# Skipped line with 2 fields: ",#Data #Analytics #DigitalTransformation
#
# Skipped line with 1 fields: "The impact of #data in every #demandgeneration campaign
#
# Skipped line with 2 fields: https://t.co/uAT96WVGRU https://t.co/wUZzBMVrL5","The impact of data in every demandgeneration campaign
#
# Skipped line with 2 fields:  ",#data #demandgeneration
#
# Skipped line with 1 fields: "The impact of #data in every #demandgeneration campaign
#
# Skipped line with 2 fields: https://t.co/xmn23TKwks https://t.co/ekmCK7dfNS","The impact of data in every demandgeneration campaign
#
# Skipped line with 2 fields:  ",#data #demandgeneration
#
# Skipped line with 5 fields: "#MongoDatabase - Have a look at this GitHub User interface knock off , using Mongodb Nodejs Express…… https://t.co/sql3hb4nCj","MongoDatabase - Have a look at this GitHub User interface knock off , using Mongodb Nodejs Express…… ",#MongoDatabase
#
# Skipped line with 1 fields: "How to Integrate #Data and #Analytics into Every Part of Your Organization | #DigitalTransformation
#
# Skipped line with 2 fields: https://t.co/1vrZ5chg7D","How to Integrate Data and Analytics into Every Part of Your Organization | DigitalTransformation
#
# Skipped line with 2 fields: ",#Data #Analytics #DigitalTransformation
#
# Skipped line with 1 fields: "RT @ThoHeller: Getting Started with #Python for #Data #Analysis. Towards #DataScience. https://t.co/TZmEFfKavq
#
# Skipped line with 2 fields: #BigData #Analytics","Getting Started with Python for Data Analysis. Towards DataScience.
#
# Skipped line with 2 fields: BigData Analytics",#Python #Data #Analysis #DataScience #BigData #Analytics
#
# Skipped line with 1 fields: "RT @ThoHeller: Getting Started with #Python for #Data #Analysis. Towards #DataScience. https://t.co/TZmEFfKavq
#
# Skipped line with 2 fields: #BigData #Analytics","Getting Started with Python for Data Analysis. Towards DataScience.
#
# Skipped line with 2 fields: BigData Analytics",#Python #Data #Analysis #DataScience #BigData #Analytics
#
# Skipped line with 5 fields: "As #IoT data floods businesses, #IT teams can ride the #data wave ?? or drown in the tsunami. @BizTechMagazine:… https://t.co/1vnClwuohu","As IoT data floods businesses, IT teams can ride the data wave ?? or drown in the tsunami. BizTechMagazine:… ",#IoT #IT #data
#
# Skipped line with 1 fields: "RT @Fisher85M: How to Design a Successful #DataLake?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #algorithm #analytics #IoT #Data #DataScience #metadata #BigData #MIO #DigitalTransfo…","How to Design a Successful DataLake?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: algorithm analytics IoT Data DataScience metadata BigData MIO DigitalTransfo…",#DataLake #algorithm #analytics #IoT #Data #DataScience #metadata #BigData #MIO #DigitalTransfo
#
# Skipped line with 7 fields: "RT @IPsoft: #AI #Amelia is a #cognitive agent at the intersection of #UI's, systems of record, and #data #platforms | https://t.co/8mUbaqOC…","AI Amelia is a cognitive agent at the intersection of UI's, systems of record, and data platforms | ",#AI #Amelia #cognitive #UI #data #platforms
#
# Skipped line with 1 fields: "RT @ipfconline1: #CyberSecurity: #Hacking The Worldwide #Banking System.
#
# Skipped line with 2 fields: #Fintech #Hackers #Data #Infosec #AI https://t.co/77YuxmHMIl","CyberSecurity: Hacking The Worldwide Banking System.
#
# Skipped line with 2 fields: Fintech Hackers Data Infosec AI ",#CyberSecurity #Hacking #Banking #Fintech #Hackers #Data #Infosec #AI
#
# Skipped line with 1 fields: "RT @Fisher85M: How to Design a Successful #DataLake?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #algorithm #analytics #IoT #Data #DataScience #metadata #BigData #MIO #DigitalTransfo…","How to Design a Successful DataLake?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: algorithm analytics IoT Data DataScience metadata BigData MIO DigitalTransfo…",#DataLake #algorithm #analytics #IoT #Data #DataScience #metadata #BigData #MIO #DigitalTransfo
#
# Skipped line with 7 fields: "#marketing #data The Path to Freedom, More Creativity, and … Really Good Audio Quality https://t.co/1Q6vPp2Xf9","marketing data The Path to Freedom, More Creativity, and … Really Good Audio Quality ",#marketing #data
#
# Skipped line with 1 fields: "RT @ThoHeller: Getting Started with #Python for #Data #Analysis. Towards #DataScience. https://t.co/TZmEFfKavq
#
# Skipped line with 2 fields: #BigData #Analytics","Getting Started with Python for Data Analysis. Towards DataScience.
#
# Skipped line with 2 fields: BigData Analytics",#Python #Data #Analysis #DataScience #BigData #Analytics
#
# Skipped line with 7 fields: "#Data makes the difference in #CX: faster decision making, greater insight on customers, increased #sales...","Data makes the difference in CX: faster decision making, greater insight on customers, increased sales...",#Data #CX #sales
#
# Skipped line with 1 fields: "RT @Redstor: The General Data Protection Regulation 101:
#
# Skipped line with 2 fields: What you need to know about the protection of your #data https://t.co/o6pp5MuGwk…","The General Data Protection Regulation 101:
#
# Skipped line with 2 fields: What you need to know about the protection of your data ",#data
#
# Skipped line with 1 fields: "RT @CelesteBeetge: The General Data Protection Regulation 101:
#
# Skipped line with 2 fields: What you need to know about the protection of your #data https://t.co/bGbZs…","The General Data Protection Regulation 101:
#
# Skipped line with 2 fields: What you need to know about the protection of your data ",#data
#
# Skipped line with 7 fields: "#Data makes the difference in #CX: faster decision making, greater insight on customers, increased #sales...","Data makes the difference in CX: faster decision making, greater insight on customers, increased sales...",#Data #CX #sales
#
# Skipped line with 5 fields: "If you're using #data 2 make decisions in your organization, you need 2 know these four daggers: https://t.co/o9Xb4lt5u4 #SH302 #leadership","If you're using data 2 make decisions in your organization, you need 2 know these four daggers:  SH302 leadership",#data #SH302 #leadership
#
# Skipped line with 1 fields: "https://t.co/VF4p1VRprG
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: "RT @ThoHeller: Getting Started with #Python for #Data #Analysis. Towards #DataScience. https://t.co/TZmEFfKavq
#
# Skipped line with 2 fields: #BigData #Analytics","Getting Started with Python for Data Analysis. Towards DataScience.
#
# Skipped line with 2 fields: BigData Analytics",#Python #Data #Analysis #DataScience #BigData #Analytics
#
# Skipped line with 5 fields: ".@SIIA Congratulates #EU &amp; #Japan on  #trade agreement, but is Disappointed with Lack of #Data Flows Provision: https://t.co/iA664sSQAa",".SIIA Congratulates EU &amp; Japan on  trade agreement, but is Disappointed with Lack of Data Flows Provision: ",#EU #Japan #trade #Data
#
# Skipped line with 1 fields: "RT @ThoHeller: How #people can kill a #data #strategy https://t.co/Je8fdbLjuS
#
# Skipped line with 1 fields: #datadriven
#
# Skipped line with 1 fields: UnshortenRe-shorten
#
# Skipped line with 2 fields: 66","How people can kill a data strategy
#
# Skipped line with 1 fields: datadriven
#
# Skipped line with 1 fields: UnshortenRe-shorten
#
# Skipped line with 2 fields: 66",#people #data #strategy #datadriven
#
# Skipped line with 5 fields: "#Data can organize milk producers and industries that need that product, Data can be business in #Tanzania","Data can organize milk producers and industries that need that product, Data can be business in Tanzania",#Data #Tanzania
#
# Skipped line with 7 fields: "#Data makes the difference in #CX: faster decision making, greater insight on customers, increased #sales...","Data makes the difference in CX: faster decision making, greater insight on customers, increased sales...",#Data #CX #sales
#
# Skipped line with 5 fields: "How the #IoT will transform every business, from smarter decision making to smarter operations. #data… https://t.co/qXmFWI09jo","How the IoT will transform every business, from smarter decision making to smarter operations. data… ",#IoT #data
#
# Skipped line with 1 fields: "UN report: 50% of countries have no #cybersecurity strategy in place- TechRep
#
# Skipped line with 1 fields: https://t.co/GQGTareYQh
#
# Skipped line with 2 fields: #business #data","UN report: 50% of countries have no cybersecurity strategy in place- TechRep
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: business data",#cybersecurity #business #data
#
# Skipped line with 7 fields: "#Data makes the difference in #CX: faster decision making, greater insight on customers, increased #sales...","Data makes the difference in CX: faster decision making, greater insight on customers, increased sales...",#Data #CX #sales
#
# Skipped line with 5 fields: "Importance of #AI, #data in law enforcement suggests growing tension with #privacy | @ZDNet  https://t.co/K3oYqDJ1Ba","Importance of AI, data in law enforcement suggests growing tension with privacy | ZDNet  ",#AI #data #privacy
#
# Skipped line with 5 fields: "RT @dma_usa: More value, less creepy: Using #data to your brand's advantage: https://t.co/8r22LXWcEo #Custexp #Marketing","More value, less creepy: Using data to your brand's advantage:  Custexp Marketing",#data #Custexp #Marketing
#
# Skipped line with 2 fields: "Access to Data Is Great, but It's How You Communicate It That Matters
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: Communication Data Access Tips Business… ",#Communication #Data #Access #Tips #Business
#
# Skipped line with 2 fields: "RT @cearta: State ‘on collision course’ with #CJEU over #data, @DRIalerts @tjmcintyre &amp; @Tupp_Ed tell Oireachtas Justice Cmmttee
#
# Skipped line with 2 fields: ",#CJEU #data
#
# Skipped line with 7 fields: "StartGrowthHack: #Data makes the difference in #CX: faster decision making, greater insight on customers, increased #sales...","StartGrowthHack: Data makes the difference in CX: faster decision making, greater insight on customers, increased sales...",#Data #CX #sales
#
# Skipped line with 7 fields: "#Data makes the difference in #CX: faster decision making, greater insight on customers, increased #sales...","Data makes the difference in CX: faster decision making, greater insight on customers, increased sales...",#Data #CX #sales
#
# Skipped line with 7 fields: "RT @6senseInc: Check out our white paper, co-written with @BOLOptimized, on the value of #search #data in the #B2B buying journey https://t…","Check out our white paper, co-written with BOLOptimized, on the value of search data in the B2B buying journey ",#search #data #B2B
#
# Skipped line with 7 fields: "Check out our white paper, co-written with @BOLOptimized, on the value of #search #data in the #B2B buying journey… https://t.co/5YoH2ySj84","Check out our white paper, co-written with BOLOptimized, on the value of search data in the B2B buying journey… ",#search #data #B2B
#
# Skipped line with 5 fields: "An intervention on marketing’s dysfunctional relationship with #data, by @RobRoy_Josh https://t.co/s6wXZO65IW via @martech_today","An intervention on marketing’s dysfunctional relationship with data, by RobRoy_Josh  via martech_today",#data
#
# Skipped line with 5 fields: "RT @GrowthAgents: Life is time and time is money, don't waste it. Don't be deaf !!! #growthhacking #growthmindset #data #DataScience https:…","Life is time and time is money, don't waste it. Don't be deaf !!! growthhacking growthmindset data DataScience ",#growthhacking #growthmindset #data #DataScience
#
# Skipped line with 1 fields: "Respond<U+278B>#Digital #Disruption
#
# Skipped line with 1 fields: <U+2139>https://t.co/vVQ6rj2vBp
#
# Skipped line with 2 fields: #Disruptive #SmartTech #AI #VR #AR #robotics #IoT #data… https://t.co/e4tqjkCTsN","Respond<U+278B>Digital Disruption
#
# Skipped line with 1 fields: <U+2139>
#
# Skipped line with 2 fields: Disruptive SmartTech AI VR AR robotics IoT data… ",#Digital #Disruption #Disruptive #SmartTech #AI #VR #AR #robotics #IoT #data
#
# Skipped line with 11 fields: "#spidering SoundCloud, the ‘YouTube for audio’, cuts 173 jobs, closes San Francisco, London…… https://t.co/OifrhRwW2a","spidering SoundCloud, the ‘YouTube for audio’, cuts 173 jobs, closes San Francisco, London…… ",#spidering
#
# Skipped line with 11 fields: "#webscraping SoundCloud, the ‘YouTube for audio’, cuts 173 jobs, closes San Francisco, London…… https://t.co/C9NlkZbNud","webscraping SoundCloud, the ‘YouTube for audio’, cuts 173 jobs, closes San Francisco, London…… ",#webscraping
#
# Skipped line with 5 fields: "RT @Datawatch: Why do 78% of organizations occasionally, rarely or never use 3rd party #data? Find out in this on-demand webinar https://t.…","Why do 78% of organizations occasionally, rarely or never use 3rd party data? Find out in this on-demand webinar ",#data
#
# Skipped line with 1 fields: "The Economics of Information: Reduce Cost &amp; Risk to Maximizes #Data Value
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #BigData #InfoSec #CIO https://t.co/zvLfnafatx","The Economics of Information: Reduce Cost &amp; Risk to Maximizes Data Value
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: BigData InfoSec CIO ",#Data #BigData #InfoSec #CIO
#
# Skipped line with 5 fields: "RT @circonus: Highly scalable &amp; robust, #IRONdb has support for replication &amp; clustering for redundancy of #data. https://t.co/cAjANf1gDr #…","Highly scalable &amp; robust, IRONdb has support for replication &amp; clustering for redundancy of data.  …",#IRONdb #data
#
# Skipped line with 5 fields: "#RideSharing companies consider their #data private and proprietary, but should cities have access to them? https://t.co/8jnjI3tQ94","RideSharing companies consider their data private and proprietary, but should cities have access to them? ",#RideSharing #data
#
# Skipped line with 5 fields: "#Marketing - Why you should start linking your pre and post purchase #data today, via @RJ_Farley https://t.co/pG0MHLLPtw","Marketing - Why you should start linking your pre and post purchase data today, via RJ_Farley ",#Marketing #data
#
# Skipped line with 1 fields: "RT @SmartDisruption: Respond<U+278B>#Digital #Disruption
#
# Skipped line with 1 fields: <U+2139>https://t.co/vVQ6rj2vBp
#
# Skipped line with 2 fields: #Disruptive #SmartTech #AI #VR #AR #robotics #IoT #data #startup…","Respond<U+278B>Digital Disruption
#
# Skipped line with 1 fields: <U+2139>
#
# Skipped line with 2 fields: Disruptive SmartTech AI VR AR robotics IoT data startup…",#Digital #Disruption #Disruptive #SmartTech #AI #VR #AR #robotics #IoT #data #startup
#
# Skipped line with 7 fields: "RT @LiftPointMN: #Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvg…","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 7 fields: "Check out MCH's Data Counts for #marketing #data segmentation and counts for #K12, #Healthcare, #Government &amp; More… https://t.co/qhywg1J2rU","Check out MCH's Data Counts for marketing data segmentation and counts for K12, Healthcare, Government &amp; More… ",#marketing #data #K12 #Healthcare #Government
#
# Skipped line with 7 fields: "RT @LiftPointMN: #Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvg…","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 1 fields: "Let's Start your own website using our affordable #dedicated #server #plans.
#
# Skipped line with 2 fields: For More Info: https://t.co/KrT1NNdlo4… https://t.co/WHAmwaY1Qv","Let's Start your own website using our affordable dedicated server plans.
#
# Skipped line with 2 fields: For More Info:  ",#dedicated #server #plans
#
# Skipped line with 1 fields: "RT @bhavesh_nardani: What is the internet of things?
#
# Skipped line with 2 fields: #data #bigdata #automation #CyberSecurity #IoT #business #privacy #Productivity https…","What is the internet of things?
#
# Skipped line with 2 fields: data bigdata automation CyberSecurity IoT business privacy Productivity ",#data #bigdata #automation #CyberSecurity #IoT #business #privacy #Productivity
#
# Skipped line with 1 fields: "RT @bhavesh_nardani: What is the internet of things?
#
# Skipped line with 2 fields: #data #bigdata #automation #CyberSecurity #IoT #business #privacy #Productivity https…","What is the internet of things?
#
# Skipped line with 2 fields: data bigdata automation CyberSecurity IoT business privacy Productivity ",#data #bigdata #automation #CyberSecurity #IoT #business #privacy #Productivity
#
# Skipped line with 5 fields: "Big #data, ERP and #IoT key to digital transformation efforts https://t.co/JeBCWqDpXj","Big data, ERP and IoT key to digital transformation efforts ",#data #IoT
#
# Skipped line with 7 fields: "RT @LiftPointMN: #Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvg…","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 2 fields: "It’s difficult to find #datascientists, so smart companies are opting to #outsource. #CMO #data #datamarketing
#
# Skipped line with 2 fields: ",#datascientists #outsource #CMO #data #datamarketing
#
# Skipped line with 7 fields: "RT @LiftPointMN: #Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvg…","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 5 fields: "RT @MSCloud: Using #Azure, @IOInteractive collects and analyzes telemetry #data from live gameplay. Read: https://t.co/kAJxPFZyec https://t…","Using Azure, IOInteractive collects and analyzes telemetry data from live gameplay. Read:  ",#Azure #data
#
# Skipped line with 5 fields: "RT @TrilliumSW: As #AI expands &amp; #data gets bigger, #DataGovernance becomes pivotal. @royalsociety w/ recs https://t.co/8QxzFyNdFH @Huffing…","As AI expands &amp; data gets bigger, DataGovernance becomes pivotal. royalsociety w/ recs  Huffing…",#AI #data #DataGovernance
#
# Skipped line with 5 fields: "RT @MongoDB: Find out how you can store your #data in #AWS, #Azure or #GCP with #MongoDB Atlas #cloud https://t.co/PRwkLS5Dwb https://t.co/…","Find out how you can store your data in AWS, Azure or GCP with MongoDB Atlas cloud  ",#data #AWS #Azure #GCP #MongoDB #cloud
#
# Skipped line with 7 fields: "Twitter - US Presidential Campaigns, Nov 7, 2015: Heat Map https://t.co/lLgiaTzYmZ #python #code #data #datascience #pandas #learn","Twitter - US Presidential Campaigns, Nov 7, 2015: Heat Map  python code data datascience pandas learn",#python #code #data #datascience #pandas #learn
#
# Skipped line with 5 fields: "Fundamentals of Descriptive Analytics: Descriptive Analytics, the… https://t.co/Mzsdns8pE7 #business #intel… https://t.co/iVwNggKm1D","Fundamentals of Descriptive Analytics: Descriptive Analytics, the…  business intel… ",#business #intel
#
# Skipped line with 7 fields: "RT @LiftPointMN: #Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvg…","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 7 fields: "RT @LiftPointMN: #Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvg…","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 7 fields: "RT @LiftPointMN: #Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvg…","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 7 fields: "RT @NYUDataScience: Can we save #nyc subways? Well, comparing our transport #data to those in #Paris, #London &amp; #HongKong sounds like a goo…","Can we save nyc subways? Well, comparing our transport data to those in Paris, London &amp; HongKong sounds like a goo…",#nyc #data #Paris #London #HongKong
#
# Skipped line with 7 fields: "#Bigdata may be the key to #energyefficiency! It’s helping #solarpower, #windpower, and more! #CMO #data https://t.co/uRvgYsLbqA","Bigdata may be the key to energyefficiency! It’s helping solarpower, windpower, and more! CMO data ",#Bigdata #energyefficiency #solarpower #windpower #CMO #data
#
# Skipped line with 5 fields: "3-year-old Rubrik copies #data in an instant in the #cloud, valued at $1bn. https://t.co/OyDQYPmmN8","3-year-old Rubrik copies data in an instant in the cloud, valued at $1bn. ",#data #cloud
#
# Skipped line with 5 fields: "Ensure your #data meets business needs, as well as governance &amp; compliance standards. https://t.co/JCQ0TJDjjB #datagovernance #iPaaS","Ensure your data meets business needs, as well as governance &amp; compliance standards.  datagovernance iPaaS",#data #datagovernance #iPaaS
#
# Skipped line with 5 fields: "RT @IBMAnalytics: If you want to be #data-driven, you need a data catalog. Start your free trial: https://t.co/KkBA9eAJjz #IBMUG https://t.…","If you want to be data-driven, you need a data catalog. Start your free trial:  IBMUG ",#data #IBMUG
#
# Skipped line with 1 fields: "RT @pradeeprao_: How #IoT is helping #School 's?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #InternetOfThings #ai #ml #BigData #Analytics #data #startup https://t.co/yv1oQpjPZp","How IoT is helping School 's?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: InternetOfThings ai ml BigData Analytics data startup ",#IoT #School #InternetOfThings #ai #ml #BigData #Analytics #data #startup
#
# Skipped line with 5 fields: "Leveraging #metagenomics &amp; big #data, @IBMResearch &amp; @CornellUnivers to protect global milk supply https://t.co/ncmXTOOdbD #foodsafety","Leveraging metagenomics &amp; big data, IBMResearch &amp; CornellUnivers to protect global milk supply  foodsafety",#metagenomics #data #foodsafety
#
# Skipped line with 5 fields: "RT @edonnellymdphd: @marygerdt Interestingly enough, I thought ST:TNG did a good job exploring some ethical issues with #Data as well.","marygerdt Interestingly enough, I thought ST:TNG did a good job exploring some ethical issues with Data as well.",#Data
#
# Skipped line with 1 fields: "Location #Data in the #Financial Services Industry
#
# Skipped line with 1 fields: https://t.co/CY3pWnIgmA
#
# Skipped line with 2 fields: #fintech #tech #CFO #banking","Location Data in the Financial Services Industry
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: fintech tech CFO banking",#Data #Financial #fintech #tech #CFO #banking
#
# Skipped line with 5 fields: "6 of the Biggest Misconceptions About #EcommerceSEO https://t.co/IgQa8Wllhl via @Visiture_search, @sejournal #searchengineoptimization #data","6 of the Biggest Misconceptions About EcommerceSEO  via Visiture_search, sejournal searchengineoptimization data",#EcommerceSEO #searchengineoptimization #data
#
# Skipped line with 5 fields: "RT @innovid: #thursdaythoughts: how do we upgrade tune-in tv? With #data, of course!  Read more over at @adexchanger --&gt; https://t.co/uPY45…","thursdaythoughts: how do we upgrade tune-in tv? With data, of course!  Read more over at adexchanger --&gt; ",#thursdaythoughts #data
#
# Skipped line with 5 fields: "RT @LookerData: Take #Looker + @googlecloud for a spin with this 4 hour test drive. No commitments, just #data exploration https://t.co/5ib…","Take Looker + googlecloud for a spin with this 4 hour test drive. No commitments, just data exploration ",#Looker #data
#
# Skipped line with 5 fields: "Regulating the #internet giants: The world’s most valuable resource is no longer oil, but #data https://t.co/fW1nyOQDFQ via @TheEconomist","Regulating the internet giants: The world’s most valuable resource is no longer oil, but data  via TheEconomist",#internet #data
#
# Skipped line with 1 fields: "What are the @Google #algorithms ?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #Google #Search #MachineLearning #deeplearning #DataScience #AI #ML #dataviz… https://t.co/kfUyaJvhoY","What are the Google algorithms ?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: Google Search MachineLearning deeplearning DataScience AI ML dataviz… ",#algorithms #Google #Search #MachineLearning #deeplearning #DataScience #AI #ML #dataviz
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 1 fields: "RT @ipfconline1: #CyberSecurity: #Hacking The Worldwide #Banking System.
#
# Skipped line with 2 fields: #Fintech #Hackers #Data #Infosec #AI https://t.co/77YuxmHMIl","CyberSecurity: Hacking The Worldwide Banking System.
#
# Skipped line with 2 fields: Fintech Hackers Data Infosec AI ",#CyberSecurity #Hacking #Banking #Fintech #Hackers #Data #Infosec #AI
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 5 fields: "RT @LookerData: Take #Looker + @googlecloud for a spin with this 4 hour test drive. No commitments, just #data exploration https://t.co/5ib…","Take Looker + googlecloud for a spin with this 4 hour test drive. No commitments, just data exploration ",#Looker #data
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 5 fields: "MSCloud: Using #Azure, IOInteractive collects and analyzes telemetry #data from live gameplay. Read: … https://t.co/Ln3TczaZVO","MSCloud: Using Azure, IOInteractive collects and analyzes telemetry data from live gameplay. Read: … ",#Azure #data
#
# Skipped line with 5 fields: "@MarkSmithVR &amp; @RiversandMDM talk on the importance of #PIM &amp; #MDM, &amp; why #cloud can help https://t.co/RK8DuWDSm2 #BigData #data","MarkSmithVR &amp; RiversandMDM talk on the importance of PIM &amp; MDM, &amp; why cloud can help  BigData data",#PIM #MDM #cloud #BigData #data
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 5 fields: "RT @janlgordon: 12 #Tools To Improve Your Visual #Content,  #Marketing and #Data  via @janlgordon @susangilbert https://t.co/v3qRQwbGjc","12 Tools To Improve Your Visual Content,  Marketing and Data  via janlgordon susangilbert ",#Tools #Content #Marketing #Data
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 1 fields: "7 myths about AI that are holding your business back
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: #AI #machinelearning #data #UX
#
# Skipped line with 2 fields: @marsinny @VentureBeat… https://t.co/Gl0sXC0NrJ","7 myths about AI that are holding your business back
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: AI machinelearning data UX
#
# Skipped line with 2 fields: marsinny VentureBeat… ",#AI #machinelearning #data #UX
#
# Skipped line with 5 fields: "Using #Azure, @IOInteractive collects and analyzes telemetry #data from live gameplay. Read: https://t.co/kAJxPFZyec https://t.co/xZtKnA8ITh","Using Azure, IOInteractive collects and analyzes telemetry data from live gameplay. Read:  ",#Azure #data
#
# Skipped line with 5 fields: ".@MerkleCRM is proud to announce the acquisition of #EU #data #analytics firm, @aquilainsight! Welcome to the team!… https://t.co/Q3dKsm8wUA",".MerkleCRM is proud to announce the acquisition of EU data analytics firm, aquilainsight! Welcome to the team!… ",#EU #data #analytics
#
# Skipped line with 5 fields: "Q: How do #brands understand company, market &amp; #product -specific #feedback w/o hiring teams of #developers #Data… https://t.co/3deMThZoJY","Q: How do brands understand company, market &amp; product -specific feedback w/o hiring teams of developers Data… ",#brands #product #feedback #developers #Data
#
# Skipped line with 5 fields: "RT @innovid: #thursdaythoughts: how do we upgrade tune-in tv? With #data, of course!  Read more over at @adexchanger --&gt; https://t.co/uPY45…","thursdaythoughts: how do we upgrade tune-in tv? With data, of course!  Read more over at adexchanger --&gt; ",#thursdaythoughts #data
#
# Skipped line with 1 fields: "RT @4orgexcellence: Why enterprises are finally paying up for #BigData security
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: https://t.co/Mh77u5Vw4C  #fintech @techrepublic #data #Cy…","Why enterprises are finally paying up for BigData security
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields:   fintech techrepublic data Cy…",#BigData #fintech #data #Cy
#
# Skipped line with 5 fields: "RT @innovid: #thursdaythoughts: how do we upgrade tune-in tv? With #data, of course!  Read more over at @adexchanger --&gt; https://t.co/uPY45…","thursdaythoughts: how do we upgrade tune-in tv? With data, of course!  Read more over at adexchanger --&gt; ",#thursdaythoughts #data
#
# Skipped line with 5 fields: "The world’s most valuable resource is no longer oil, but #data @TheEconomist https://t.co/8UMvE7eoQe https://t.co/45keDofLW3","The world’s most valuable resource is no longer oil, but data TheEconomist  ",#data
#
# Skipped line with 5 fields: "Excellent summary of Data Challenges and Tips. #Data policies and governance, \start small think big\"" #BeFirst https://t.co/hjJSHqyjRA""","Excellent summary of Data Challenges and Tips. Data policies and governance, \start small think big\"" BeFirst ",#Data #BeFirst
#
# Skipped line with 5 fields: "Manage what matters most by tapping into the power of #data, which has become ubiquitous in both business and life<U+200B>… https://t.co/DgjyYV8tS0","Manage what matters most by tapping into the power of data, which has become ubiquitous in both business and life<U+200B>… ",#data
#
# Skipped line with 1 fields: "RT @BourseetTrading: <ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A #data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 2 fields: h…","<ed><U+00A0><U+00BD><ed><U+00B4><U+00B4>A data-driven revolution is sweeping through the investment industry
#
# Skipped line with 1 fields: fintech defstar5 makeyourownlane Mpgvip
#
# Skipped line with 2 fields: h…",#data #fintech #defstar5 #makeyourownlane #Mpgvip
#
# Skipped line with 1 fields: "RT @BigDataLoop: #Data #Strategy in 4 Steps!
#
# Skipped line with 2 fields: #digitaltransformation #business #startups #fintech #defstar5 #makeyourownlane #Mpgvip #bigdat…","Data Strategy in 4 Steps!
#
# Skipped line with 2 fields: digitaltransformation business startups fintech defstar5 makeyourownlane Mpgvip bigdat…",#Data #Strategy #digitaltransformation #business #startups #fintech #defstar5 #makeyourownlane #Mpgvip #bigdat
#
# Skipped line with 1 fields: "RT @spotlessdata: External article:
#
# Skipped line with 1 fields: Weathering the #Data Storm – 4 Steps to Analytics Success
#
# Skipped line with 1 fields: https://t.co/iFKpT05Tmk
#
# Skipped line with 2 fields: #DataQuality","External article:
#
# Skipped line with 1 fields: Weathering the Data Storm – 4 Steps to Analytics Success
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: DataQuality",#Data #DataQuality
#
# Skipped line with 1 fields: "External article:
#
# Skipped line with 1 fields: Weathering the #Data Storm – 4 Steps to Analytics Success
#
# Skipped line with 1 fields: https://t.co/iFKpT05Tmk
#
# Skipped line with 2 fields: #DataQuality","External article:
#
# Skipped line with 1 fields: Weathering the Data Storm – 4 Steps to Analytics Success
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: DataQuality",#Data #DataQuality
#
# Skipped line with 1 fields: "#NYC #JOBS #ProductManager #data #revenue #subscriptions #agile #loyalty
#
# Skipped line with 2 fields: DM me  https://t.co/rHX8xk9kPB","NYC JOBS ProductManager data revenue subscriptions agile loyalty
#
# Skipped line with 2 fields: DM me  ",#NYC #JOBS #ProductManager #data #revenue #subscriptions #agile #loyalty
#
# Skipped line with 1 fields: "Magic Quadrant for #Data #Center #Networking
#
# Skipped line with 1 fields: https://t.co/qcY4c3YoJh
#
# Skipped line with 2 fields: Very interesting view on Enterprise Networking and #SDN #vExpertNSX","Magic Quadrant for Data Center Networking
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: Very interesting view on Enterprise Networking and SDN vExpertNSX",#Data #Center #Networking #SDN #vExpertNSX
#
# Skipped line with 1 fields: "Why Big Data is Important for Businesses https://t.co/Fm9heSGvci via @B2Community
#
# Skipped line with 2 fields: #bigdata #data #info #UX #DX #IoT #CEO","Why Big Data is Important for Businesses  via B2Community
#
# Skipped line with 2 fields: bigdata data info UX DX IoT CEO",#bigdata #data #info #UX #DX #IoT #CEO
#
# Skipped line with 5 fields: "RT @EricCaiEA: #Canada’s Best Places to Live for 2017 has been released by @MoneySense, with much #data provided by @EnvironicsA: https://t…","Canada’s Best Places to Live for 2017 has been released by MoneySense, with much data provided by EnvironicsA: ",#Canada #data
#
# Skipped line with 1 fields: "The data synthesis challenge: How to integrate and analyze scattered #enterprise #data
#
# Skipped line with 2 fields: https://t.co/6hhSvfpEqL","The data synthesis challenge: How to integrate and analyze scattered enterprise data
#
# Skipped line with 2 fields: ",#enterprise #data
#
# Skipped line with 1 fields: "“The Goal is to turn Data into Information and Information into Insight” https://t.co/nyoczh1wk9
#
# Skipped line with 2 fields: #Data #DataAnalysis https://t.co/53hFIkggze","“The Goal is to turn Data into Information and Information into Insight”
#
# Skipped line with 2 fields: Data DataAnalysis ",#Data #DataAnalysis
#
# Skipped line with 5 fields: "Do you host your #BigData environment in the #cloud, or create a #data lake on-site? https://t.co/zSkm73Waic https://t.co/mVLA5HljZE","Do you host your BigData environment in the cloud, or create a data lake on-site?  ",#BigData #cloud #data
#
# Skipped line with 5 fields: "RT @infobldrs: New research indicates disconnected #data is costing orgs $140B annually, reports @BobViolino at @infomgmt: https://t.co/1rP…","New research indicates disconnected data is costing orgs $140B annually, reports BobViolino at infomgmt: ",#data
#
# Skipped line with 1 fields: "RT @BigDataLoop: #Data #Strategy in 4 Steps!
#
# Skipped line with 2 fields: #digitaltransformation #business #startups #fintech #defstar5 #makeyourownlane #Mpgvip #bigdat…","Data Strategy in 4 Steps!
#
# Skipped line with 2 fields: digitaltransformation business startups fintech defstar5 makeyourownlane Mpgvip bigdat…",#Data #Strategy #digitaltransformation #business #startups #fintech #defstar5 #makeyourownlane #Mpgvip #bigdat
#
# Skipped line with 5 fields: "#Infographic #Data A Guide to Aging in Place - Most seniors prefer to age in place, in the comfort of their own... https://t.co/Jb9NtiZsL8","Infographic Data A Guide to Aging in Place - Most seniors prefer to age in place, in the comfort of their own... ",#Infographic #Data
#
# Skipped line with 1 fields: "RT @datacentresire: @Opengear exhibiting @datacentresire see them on stand 321! Interested in exhibiting see stand costs below #data
#
# Skipped line with 2 fields: https:…","Opengear exhibiting datacentresire see them on stand 321! Interested in exhibiting see stand costs below data
#
# Skipped line with 2 fields: ",#data
#
# Skipped line with 5 fields: "Importance of #AI, #data in #law enforcement suggests growing tension with #privacy https://t.co/rkglFpHzd3 via @ZDNet &amp; @eileenscyu","Importance of AI, data in law enforcement suggests growing tension with privacy  via ZDNet &amp; eileenscyu",#AI #data #law #privacy
#
# Skipped line with 1 fields: "RT SpirosMargaris: The Age Of #Data  Has Arrived
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: https://t.co/tfFoeQd2F0 #Fintech Ceterna #BigData #aI #MachineLearning Info_Se…","RT SpirosMargaris: The Age Of Data  Has Arrived
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields:  Fintech Ceterna BigData aI MachineLearning Info_Se…",#Data #Fintech #BigData #aI #MachineLearning
#
# Skipped line with 5 fields: "Due diligence failings spark £50,000 fine for TPS abuse - Industry News https://t.co/dwnthiV1b5 #data #marketing… https://t.co/2sCyX4CxH5","Due diligence failings spark £50,000 fine for TPS abuse - Industry News  data marketing… ",#data #marketing
#
# Skipped line with 1 fields: "RT @DomenicaCresap: Lyft Aims at a Self-Driving Future With More Partnerships
#
# Skipped line with 2 fields: https://t.co/wbT7TTfiuz #technology #tech #data","Lyft Aims at a Self-Driving Future With More Partnerships
#
# Skipped line with 2 fields:  technology tech data",#technology #tech #data
#
# Skipped line with 5 fields: "RT @EricCaiEA: #Canada’s Best Places to Live for 2017 has been released by @MoneySense, with much #data provided by @EnvironicsA: https://t…","Canada’s Best Places to Live for 2017 has been released by MoneySense, with much data provided by EnvironicsA: ",#Canada #data
#
# Skipped line with 1 fields: "RT @DomenicaCresap: Former #Intel Exec Ready to Help Bring Broadband to Rural #Colorado
#
# Skipped line with 2 fields: https://t.co/CAlF4OB8uL #infosec #IT #data #iot","Former Intel Exec Ready to Help Bring Broadband to Rural Colorado
#
# Skipped line with 2 fields:  infosec IT data iot",#Intel #Colorado #infosec #IT #data #iot
#
# Skipped line with 1 fields: "RT @DomenicaCresap: When is real-time analytics the right #analytics?
#
# Skipped line with 2 fields: https://t.co/wu93DbMsCL #data #business #IT","When is real-time analytics the right analytics?
#
# Skipped line with 2 fields:  data business IT",#analytics #data #business #IT
#
# Skipped line with 5 fields: "Stop Burning Money, Use These Google #Analytics Reports Instead https://t.co/vPIqfdFK3L via @ShopifyPlus #data","Stop Burning Money, Use These Google Analytics Reports Instead  via ShopifyPlus data",#Analytics #data
#
# Skipped line with 1 fields: "RT @TechNative: Why #data #availability is central to attracting the next generation of #talent
#
# Skipped line with 1 fields: (via #Cloud28+ @veeam) #HRTech #BYOD
#
# Skipped line with 2 fields: https:…","Why data availability is central to attracting the next generation of talent
#
# Skipped line with 1 fields: (via Cloud28+ veeam) HRTech BYOD
#
# Skipped line with 2 fields: ",#data #availability #talent #Cloud28 #HRTech #BYOD
#
# Skipped line with 1 fields: "RT @TechNative: Why #data #availability is central to attracting the next generation of #talent
#
# Skipped line with 1 fields: (via #Cloud28+ @veeam) #HRTech #BYOD
#
# Skipped line with 2 fields: https:…","Why data availability is central to attracting the next generation of talent
#
# Skipped line with 1 fields: (via Cloud28+ veeam) HRTech BYOD
#
# Skipped line with 2 fields: ",#data #availability #talent #Cloud28 #HRTech #BYOD
#
# Skipped line with 1 fields: "RT @TechNative: Why #data #availability is central to attracting the next generation of #talent
#
# Skipped line with 1 fields: (via #Cloud28+ @veeam) #HRTech #BYOD
#
# Skipped line with 2 fields: https:…","Why data availability is central to attracting the next generation of talent
#
# ...
#
# Skipped line with 2 fields:  DataScience MachineLearning Clou…",#BigData #DataScience #MachineLearning #Clou
#
# Skipped line with 1 fields: "RT @DeepAdvantage: The Landscape of #BigData
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: #infographics
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #IoT #Analytics #Mobile #Digital #Startups #datascience #dataanalytics #tech…","The Landscape of BigData
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: infographics
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: IoT Analytics Mobile Digital Startups datascience dataanalytics tech…",#BigData #infographics #IoT #Analytics #Mobile #Digital #Startups #datascience #dataanalytics #tech
#
# Skipped line with 1 fields: "RT @Fisher85M: How to #analyze massive amount of #data?
#
# Skipped line with 2 fields: #DataScience #BigData #ML #datalake #AI #Analytics #PredictiveAnalytics #dataviz ht…","How to analyze massive amount of data?
#
# Skipped line with 2 fields: DataScience BigData ML datalake AI Analytics PredictiveAnalytics dataviz ht…",#analyze #data #DataScience #BigData #ML #datalake #AI #Analytics #PredictiveAnalytics #dataviz
#
# Skipped line with 1 fields: "RT @DeepAdvantage: The Landscape of #BigData
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: #infographics
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #IoT #Analytics #Mobile #Digital #Startups #datascience #dataanalytics #tech…","The Landscape of BigData
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: infographics
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: IoT Analytics Mobile Digital Startups datascience dataanalytics tech…",#BigData #infographics #IoT #Analytics #Mobile #Digital #Startups #datascience #dataanalytics #tech
#
# Skipped line with 1 fields: "RT @gp_pulipaka: #DeepLearning <U+200A>—<U+200A>the next step for Recommendation systems? #BigData  #MachineLearning #DataScience #AI #RecSys
#
# Skipped line with 2 fields: https://t.c…","DeepLearning <U+200A>—<U+200A>the next step for Recommendation systems? BigData  MachineLearning DataScience AI RecSys
#
# Skipped line with 2 fields: ",#DeepLearning #BigData #MachineLearning #DataScience #AI #RecSys
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Using Virtual Reality For Ethical Decisions in Road Traffic Scenarios. #BigData #MachineLearning #DataScience #AI
#
# Skipped line with 2 fields: https://…","Using Virtual Reality For Ethical Decisions in Road Traffic Scenarios. BigData MachineLearning DataScience AI
#
# Skipped line with 2 fields: ",#BigData #MachineLearning #DataScience #AI
#
# Skipped line with 7 fields: "RT @5aff: Fully-funded #PhD combining #datascience, #mobilecomputing, and #userexperience. Deadline 31 July. https://t.co/3JRuLi0u5s","Fully-funded PhD combining datascience, mobilecomputing, and userexperience. Deadline 31 July. ",#PhD #datascience #mobilecomputing #userexperience
#
# Skipped line with 1 fields: "RT @pradeeprao_: Are you ready for #cloud #bigdata &amp; #IoT ?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #startup #business #fintech #ML #datascience #blockchain #technology #tech htt…","Are you ready for cloud bigdata &amp; IoT ?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: startup business fintech ML datascience blockchain technology tech htt…",#cloud #bigdata #IoT #startup #business #fintech #ML #datascience #blockchain #technology #tech
#
# Skipped line with 1 fields: "RT @ipfconline1: The Evolution of #IoT [Infographic]
#
# Skipped line with 1 fields: [via @topij @CalliauF]
#
# Skipped line with 2 fields: #BigData #DataScience #Chatbot #Fintech #Insurtech #AI #VR #AR…","The Evolution of IoT [Infographic]
#
# Skipped line with 1 fields: [via topij CalliauF]
#
# Skipped line with 2 fields: BigData DataScience Chatbot Fintech Insurtech AI VR AR…",#IoT #BigData #DataScience #Chatbot #Fintech #Insurtech #AI #VR #AR
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Will Brain-Inspired Chips Make a Dent in #BigDataProblems?  #DeepLearning #MachineLearning #DataScience #AI #IBM
#
# Skipped line with 2 fields: https://t…","Will Brain-Inspired Chips Make a Dent in BigDataProblems?  DeepLearning MachineLearning DataScience AI IBM
#
# Skipped line with 2 fields: ",#BigDataProblems #DeepLearning #MachineLearning #DataScience #AI #IBM
#
# Skipped line with 1 fields: "RT @gp_pulipaka: #DeepLearning <U+200A>—<U+200A>the next step for Recommendation systems? #BigData  #MachineLearning #DataScience #AI #RecSys
#
# Skipped line with 2 fields: https://t.c…","DeepLearning <U+200A>—<U+200A>the next step for Recommendation systems? BigData  MachineLearning DataScience AI RecSys
#
# Skipped line with 2 fields: ",#DeepLearning #BigData #MachineLearning #DataScience #AI #RecSys
#
# Skipped line with 1 fields: "RT @pradeeprao_: Who's driving #AI?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #DataScience #ArtificialIntelligence #PredictiveAnalytics #PwC #MachineLearning By @MikeQuindazzi @ev…","Who's driving AI?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: DataScience ArtificialIntelligence PredictiveAnalytics PwC MachineLearning By MikeQuindazzi ev…",#AI #DataScience #ArtificialIntelligence #PredictiveAnalytics #PwC #MachineLearning
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Will Brain-Inspired Chips Make a Dent in #BigDataProblems?  #DeepLearning #MachineLearning #DataScience #AI #IBM
#
# Skipped line with 2 fields: https://t…","Will Brain-Inspired Chips Make a Dent in BigDataProblems?  DeepLearning MachineLearning DataScience AI IBM
#
# Skipped line with 2 fields: ",#BigDataProblems #DeepLearning #MachineLearning #DataScience #AI #IBM
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Will Brain-Inspired Chips Make a Dent in #BigDataProblems?  #DeepLearning #MachineLearning #DataScience #AI #IBM
#
# Skipped line with 2 fields: https://t…","Will Brain-Inspired Chips Make a Dent in BigDataProblems?  DeepLearning MachineLearning DataScience AI IBM
#
# Skipped line with 2 fields: ",#BigDataProblems #DeepLearning #MachineLearning #DataScience #AI #IBM
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Deep Learning with #Keras. #BigData #DeepLearning #MachinLearning #DataScience #AI #Books
#
# Skipped line with 2 fields: https://t.co/BRuEA2e4TF https://…","Deep Learning with Keras. BigData DeepLearning MachinLearning DataScience AI Books
#
# Skipped line with 2 fields:  ",#Keras #BigData #DeepLearning #MachinLearning #DataScience #AI #Books
#
# Skipped line with 1 fields: "RT @ParallelRecruit: Anaconda &amp; #Python Appeal to Data Scientists
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: https://t.co/moUAulIxMb via @DZone
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #DataScience #DataScientist #bigdata…","Anaconda &amp; Python Appeal to Data Scientists
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields:  via DZone
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: DataScience DataScientist bigdata…",#Python #DataScience #DataScientist #bigdata
#
# Skipped line with 1 fields: "RT @KirkDBorne: Where's the Big Money in #BigData? Has the Gold Rush Gone Bust?
#
# Skipped line with 2 fields: https://t.co/fy8Cp4IPMC #DataScience #MachineLearning #Clou…","Where's the Big Money in BigData? Has the Gold Rush Gone Bust?
#
# Skipped line with 2 fields:  DataScience MachineLearning Clou…",#BigData #DataScience #MachineLearning #Clou
#
# Skipped line with 1 fields: "RT @ipfconline1: 12 #BigData Predictions You Shouldn't Miss
#
# Skipped line with 2 fields: #Privacy #AI #DataScience #ML #ArtificialIntelligence #Tech https://t.co/MhU10B…","12 BigData Predictions You Shouldn't Miss
#
# Skipped line with 2 fields: Privacy AI DataScience ML ArtificialIntelligence Tech ",#BigData #Privacy #AI #DataScience #ML #ArtificialIntelligence #Tech
#
# Skipped line with 1 fields: "RT @gp_pulipaka: #DeepLearning <U+200A>—<U+200A>the next step for Recommendation systems? #BigData  #MachineLearning #DataScience #AI #RecSys
#
# Skipped line with 2 fields: https://t.c…","DeepLearning <U+200A>—<U+200A>the next step for Recommendation systems? BigData  MachineLearning DataScience AI RecSys
#
# Skipped line with 2 fields: ",#DeepLearning #BigData #MachineLearning #DataScience #AI #RecSys
#
# Skipped line with 5 fields: "RT @andrewshamlet: Targeting an Audience, Mapping a Tour: Luther Dickinson https://t.co/7XXYsMbEzj #python #code #data #datascience #pandas…","Targeting an Audience, Mapping a Tour: Luther Dickinson  python code data datascience pandas…",#python #code #data #datascience #pandas
#
# Skipped line with 5 fields: "Targeting an Audience, Mapping a Tour: Luther Dickinson https://t.co/7XXYsMbEzj #python #code #data #datascience #pandas #learn","Targeting an Audience, Mapping a Tour: Luther Dickinson  python code data datascience pandas learn",#python #code #data #datascience #pandas #learn
#
# Skipped line with 1 fields: "Anaconda &amp; #Python Appeal to Data Scientists
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields: https://t.co/moUAulIxMb via @DZone
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #DataScience #DataScientist… https://t.co/UUEVRDG2xx","Anaconda &amp; Python Appeal to Data Scientists
#
# Skipped line with 1 fields:
#
# Skipped line with 1 fields:  via DZone
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: DataScience DataScientist… ",#Python #DataScience #DataScientist
#
# Skipped line with 1 fields: "RT @ipfconline1: 40 Techniques Used by Data Scientists
#
# Skipped line with 1 fields: https://t.co/gO61XxKUVh    [via @DataScienceCtrl]
#
# Skipped line with 2 fields: #DataScience #MachineLearning #AI…","40 Techniques Used by Data Scientists
#
# Skipped line with 1 fields:     [via DataScienceCtrl]
#
# Skipped line with 2 fields: DataScience MachineLearning AI…",#DataScience #MachineLearning #AI
#
# Skipped line with 1 fields: "RT @pradeeprao_: Who's driving #AI?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #DataScience #ArtificialIntelligence #PredictiveAnalytics #PwC #MachineLearning By @MikeQuindazzi @ev…","Who's driving AI?
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: DataScience ArtificialIntelligence PredictiveAnalytics PwC MachineLearning By MikeQuindazzi ev…",#AI #DataScience #ArtificialIntelligence #PredictiveAnalytics #PwC #MachineLearning
#
# Skipped line with 13 fields: "RT @KirkDBorne: 20 Cheat Sheets for #Python, #ML, #DataScience, R, #Statistics,.. https://t.co/Px2SrpePqS #abdsc #Rstats #BigData #MachineL…","20 Cheat Sheets for Python, ML, DataScience, R, Statistics,..  abdsc Rstats BigData MachineL…",#Python #ML #DataScience #Statistics #abdsc #Rstats #BigData #MachineL
#
# Skipped line with 13 fields: "RT @KirkDBorne: 20 Cheat Sheets for #Python, #ML, #DataScience, R, #Statistics,.. https://t.co/Px2SrpePqS #abdsc #Rstats #BigData #MachineL…","20 Cheat Sheets for Python, ML, DataScience, R, Statistics,..  abdsc Rstats BigData MachineL…",#Python #ML #DataScience #Statistics #abdsc #Rstats #BigData #MachineL
#
# Skipped line with 1 fields: "RT @ipfconline1: 40 Techniques Used by Data Scientists
#
# Skipped line with 1 fields: https://t.co/gO61XxKUVh    [via @DataScienceCtrl]
#
# Skipped line with 2 fields: #DataScience #MachineLearning #AI…","40 Techniques Used by Data Scientists
#
# Skipped line with 1 fields:     [via DataScienceCtrl]
#
# Skipped line with 2 fields: DataScience MachineLearning AI…",#DataScience #MachineLearning #AI
#
# Skipped line with 1 fields: "RT @ipfconline1: 40 Techniques Used by Data Scientists
#
# Skipped line with 1 fields: https://t.co/gO61XxKUVh    [via @DataScienceCtrl]
#
# Skipped line with 2 fields: #DataScience #MachineLearning #AI…","40 Techniques Used by Data Scientists
#
# Skipped line with 1 fields:     [via DataScienceCtrl]
#
# Skipped line with 2 fields: DataScience MachineLearning AI…",#DataScience #MachineLearning #AI
#
# Skipped line with 1 fields: "RT @JacBurns_Comext: How #ArtificialIntelligence Will Shape #eLearning For Good https://t.co/d8EQarWIrD
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #MachineLearning #DataScience #Dee…","How ArtificialIntelligence Will Shape eLearning For Good
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: MachineLearning DataScience Dee…",#ArtificialIntelligence #eLearning #MachineLearning #DataScience #Dee
#
# Skipped line with 1 fields: "RT @Fisher85M: #IoT attacks: #Top10 things you need to know
#
# Skipped line with 2 fields: #CyberSecurity #infosec #Security #DDoS #BigData #DataScience #antivirus #Hacki…","IoT attacks: Top10 things you need to know
#
# Skipped line with 2 fields: CyberSecurity infosec Security DDoS BigData DataScience antivirus Hacki…",#IoT #Top10 #CyberSecurity #infosec #Security #DDoS #BigData #DataScience #antivirus #Hacki
#
# Skipped line with 5 fields: "RT @DSIDataExperts: Read about our new video series, Advanced Analytics Using R! https://t.co/kdfQVMdgPH #datascience #technology #Microsof…","Read about our new video series, Advanced Analytics Using R!  datascience technology Microsof…",#datascience #technology #Microsof
#
# Skipped line with 1 fields: "RT @Fisher85M: #IoT attacks: #Top10 things you need to know
#
# Skipped line with 2 fields: #CyberSecurity #infosec #Security #DDoS #BigData #DataScience #antivirus #Hacki…","IoT attacks: Top10 things you need to know
#
# Skipped line with 2 fields: CyberSecurity infosec Security DDoS BigData DataScience antivirus Hacki…",#IoT #Top10 #CyberSecurity #infosec #Security #DDoS #BigData #DataScience #antivirus #Hacki
#
# Skipped line with 1 fields: "RT @CntactDBLindsey: 10 #BigData Trends in 2017
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #Ecommerce #DataScience #SMM  #SocialMedia #machinelearning #analytics #SEO #IoT #emailmar…","10 BigData Trends in 2017
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: Ecommerce DataScience SMM  SocialMedia machinelearning analytics SEO IoT emailmar…",#BigData #Ecommerce #DataScience #SMM #SocialMedia #machinelearning #analytics #SEO #IoT #emailmar
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Deep Reinforcement Learning For Social Dilemmas. #BigData #DeepLearning #MachineLearning #DataScience #AI
#
# Skipped line with 2 fields: https://t.co/oy…","Deep Reinforcement Learning For Social Dilemmas. BigData DeepLearning MachineLearning DataScience AI
#
# Skipped line with 2 fields: ",#BigData #DeepLearning #MachineLearning #DataScience #AI
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Using Virtual Reality For Ethical Decisions in Road Traffic Scenarios. #BigData #MachineLearning #DataScience #AI
#
# Skipped line with 2 fields: https://…","Using Virtual Reality For Ethical Decisions in Road Traffic Scenarios. BigData MachineLearning DataScience AI
#
# Skipped line with 2 fields: ",#BigData #MachineLearning #DataScience #AI
#
# Skipped line with 1 fields: "RT @gp_pulipaka: Deep Learning with #Keras. #BigData #DeepLearning #MachinLearning #DataScience #AI #Books
#
# Skipped line with 2 fields: https://t.co/BRuEA2e4TF https://…","Deep Learning with Keras. BigData DeepLearning MachinLearning DataScience AI Books
#
# Skipped line with 2 fields:  ",#Keras #BigData #DeepLearning #MachinLearning #DataScience #AI #Books
#
# Skipped line with 1 fields: "RT @CntactDBLindsey: 10 #BigData Trends in 2017
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: #Ecommerce #DataScience #SMM  #SocialMedia #machinelearning #analytics #SEO #IoT #emailmar…","10 BigData Trends in 2017
#
# Skipped line with 1 fields:
#
# Skipped line with 2 fields: Ecommerce DataScience SMM  SocialMedia machinelearning analytics SEO IoT emailmar…",#BigData #Ecommerce #DataScience #SMM #SocialMedia #machinelearning #analytics #SEO #IoT #emailmar
#
# Skipped line with 7 fields: "RT @5aff: Fully-funded #PhD combining #datascience, #mobilecomputing, and #userexperience. Deadline 31 July. https://t.co/3JRuLi0u5s","Fully-funded PhD combining datascience, mobilecomputing, and userexperience. Deadline 31 July. ",#PhD #datascience #mobilecomputing #userexperience

# %%
# Remove Duplicates
tweets= tweets.drop_duplicates(subset="Post")

# %%
#Handle missing Values
tweets = tweets.dropna()

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased", token="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")

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+','',text)
    text = re.sub(r'[^a-zA-Z0-9\s]','',text)
    return text

def clean_hashtags(hashtags_list):
    cleaned_tags_list = []
    for hashtags_str in hashtags_list:
        cleaned_tags = []
        for tag in hashtags_str.split('#'):
            if tag.strip() != '':
                cleaned_tags.append(tag.strip())
        cleaned_tags_list.append(cleaned_tags)
    return cleaned_tags_list

# %%
tweets['Clean_Text'] = tweets['Text'].apply(clean_text)
tweets['Cleaned_Hashtags'] = clean_hashtags(tweets['Hashtags'])

# %%
tweets.head()
# Out:
#                                                 Post  \
# 0  Looking Ahead: 17 #Predicted #Marketing #Trend...
# 1  RT @simonnash2017: These are the #Top20 #BigDa...
# 2  These are the #Top20 #BigData &amp; #AI on #tw...
# 3  RT @Azure: Data is evolving. Find out how to t...
# 4  These are the #Top20 #BigData &amp; #AI on #tw...
#
#                                                 Text  \
# 0  Looking Ahead: 17 Predicted Marketing Trends I...
# 1  These are the Top20 BigData &amp; AI on twitte...
# 2  These are the Top20 BigData &amp; AI on twitte...
# 3  Data is evolving. Find out how to transform yo...
# 4  These are the Top20 BigData &amp; AI on twitte...
#
#                                             Hashtags  \
# 0  #Predicted #Marketing #Trends #Mobile #AR #VR ...
# 1  #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
# 2  #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
# 3                                         #SQL #Data
# 4  #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
#
#                                           Clean_Text  \
# 0  looking ahead 17 predicted marketing trends in...
# 1  these are the top20 bigdata amp ai on twitter ...
# 2  these are the top20 bigdata amp ai on twitter ...
# 3  data is evolving find out how to transform you...
# 4  these are the top20 bigdata amp ai on twitter ...
#
#                                     Cleaned_Hashtags
# 0  [Predicted, Marketing, Trends, Mobile, AR, VR,...
# 1  [Top20, BigData, AI, twitter, 2017, ITjobs, Da...
# 2  [Top20, BigData, AI, twitter, 2017, ITjobs, Da...
# 3                                        [SQL, Data]
# 4  [Top20, BigData, AI, twitter, 2017, ITjobs, Da...

# %%
# Tokenize the text and hashtags
tweets['text_tokens'] = tweets['Text'].apply(lambda text: tokenizer.encode(text, add_special_tokens=True, truncation=True, max_length=128))
tweets['hashtags_tokens'] = tweets['Hashtags'].apply(lambda hashtags: [tokenizer.encode(tag, add_special_tokens=False) for tag in hashtags])

# %%
# Combine text and hashtags tokens
tweets['input_tokens'] = tweets.apply(lambda row: row['text_tokens'] + [tokenizer.sep_token_id] + [token for tag_tokens in row['hashtags_tokens'] for token in tag_tokens], axis=1)

# %%
# removing null values
tweets.dropna()
# Out:
#                                                    Post  \
# 0     Looking Ahead: 17 #Predicted #Marketing #Trend...
# 1     RT @simonnash2017: These are the #Top20 #BigDa...
# 2     These are the #Top20 #BigData &amp; #AI on #tw...
# 3     RT @Azure: Data is evolving. Find out how to t...
# 4     These are the #Top20 #BigData &amp; #AI on #tw...
# ...                                                 ...
# 1290  RT @turinginst: Apply: We're hosting an Urban ...
# 1293  binaryloom: RT reach2ratan: What is #Bigdata? ...
# 1297  10 Rules for Creating Reproducible Results in ...
# 1310  RT @dj_shaily: @gp_pulipaka: Deep Reinforcemen...
# 1311  Recommendation System Algorithms https://t.co/...
#
#                                                    Text  \
# 0     Looking Ahead: 17 Predicted Marketing Trends I...
# 1     These are the Top20 BigData &amp; AI on twitte...
# 2     These are the Top20 BigData &amp; AI on twitte...
# 3     Data is evolving. Find out how to transform yo...
# 4     These are the Top20 BigData &amp; AI on twitte...
# ...                                                 ...
# 1290  Apply: We're hosting an Urban Analytics DataDi...
# 1293  binaryloom: RT reach2ratan: What is Bigdata?  ...
# 1297  10 Rules for Creating Reproducible Results in ...
# 1310  gp_pulipaka: Deep Reinforcement Learning For S...
# 1311  Recommendation System Algorithms  datascience ...
#
#                                                Hashtags  \
# 0     #Predicted #Marketing #Trends #Mobile #AR #VR ...
# 1     #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
# 2     #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
# 3                                            #SQL #Data
# 4     #Top20 #BigData #AI #twitter #2017 #ITjobs #Da...
# ...                                                 ...
# 1290                             #DataDive #datascience
# 1293  #Bigdata #datascience #analytics #makeyourownl...
# 1297                                       #DataScience
# 1310  #BigData #DeepLearning #MachineLearning #DataS...
# 1311                            #datascience #analytics
#
#                                              Clean_Text  \
# 0     looking ahead 17 predicted marketing trends in...
# 1     these are the top20 bigdata amp ai on twitter ...
# 2     these are the top20 bigdata amp ai on twitter ...
# 3     data is evolving find out how to transform you...
# 4     these are the top20 bigdata amp ai on twitter ...
# ...                                                 ...
# 1290  apply were hosting an urban analytics datadive...
# 1293  binaryloom rt reach2ratan what is bigdata  dat...
# 1297  10 rules for creating reproducible results in ...
# 1310  gppulipaka deep reinforcement learning for soc...
# 1311  recommendation system algorithms  datascience ...
#
#                                        Cleaned_Hashtags  \
# 0     [Predicted, Marketing, Trends, Mobile, AR, VR,...
# 1     [Top20, BigData, AI, twitter, 2017, ITjobs, Da...
# 2     [Top20, BigData, AI, twitter, 2017, ITjobs, Da...
# 3                                           [SQL, Data]
# 4     [Top20, BigData, AI, twitter, 2017, ITjobs, Da...
# ...                                                 ...
# 1290                            [DataDive, datascience]
# 1293  [Bigdata, datascience, analytics, makeyourownl...
# 1297                                      [DataScience]
# 1310  [BigData, DeepLearning, MachineLearning, DataS...
# 1311                           [datascience, analytics]
#
#                                             text_tokens  \
# 0     [101, 2559, 3805, 1024, 2459, 10173, 5821, 128...
# 1     [101, 2122, 2024, 1996, 2327, 11387, 2502, 285...
# 2     [101, 2122, 2024, 1996, 2327, 11387, 2502, 285...
# 3     [101, 2951, 2003, 20607, 1012, 2424, 2041, 212...
# 4     [101, 2122, 2024, 1996, 2327, 11387, 2502, 285...
# ...                                                 ...
# 1290  [101, 6611, 1024, 2057, 1005, 2128, 9936, 2019...
# 1293  [101, 12441, 4135, 5358, 1024, 19387, 3362, 24...
# 1297  [101, 2184, 3513, 2005, 4526, 16360, 14127, 21...
# 1310  [101, 14246, 1035, 16405, 15000, 11905, 1024, ...
# 1311  [101, 12832, 2291, 13792, 2951, 11020, 13684, ...
#
#                                         hashtags_tokens  \
# 0     [[1001], [1052], [1054], [1041], [1040], [1045...
# 1     [[1001], [1056], [1051], [1052], [1016], [1014...
# 2     [[1001], [1056], [1051], [1052], [1016], [1014...
# 3     [[1001], [1055], [1053], [1048], [], [1001], [...
# 4     [[1001], [1056], [1051], [1052], [1016], [1014...
# ...                                                 ...
# 1290  [[1001], [1040], [1037], [1056], [1037], [1040...
# 1293  [[1001], [1038], [1045], [1043], [1040], [1037...
# 1297  [[1001], [1040], [1037], [1056], [1037], [1055...
# 1310  [[1001], [1038], [1045], [1043], [1040], [1037...
# 1311  [[1001], [1040], [1037], [1056], [1037], [1055...
#
#                                            input_tokens
# 0     [101, 2559, 3805, 1024, 2459, 10173, 5821, 128...
# 1     [101, 2122, 2024, 1996, 2327, 11387, 2502, 285...
# 2     [101, 2122, 2024, 1996, 2327, 11387, 2502, 285...
# 3     [101, 2951, 2003, 20607, 1012, 2424, 2041, 212...
# 4     [101, 2122, 2024, 1996, 2327, 11387, 2502, 285...
# ...                                                 ...
# 1290  [101, 6611, 1024, 2057, 1005, 2128, 9936, 2019...
# 1293  [101, 12441, 4135, 5358, 1024, 19387, 3362, 24...
# 1297  [101, 2184, 3513, 2005, 4526, 16360, 14127, 21...
# 1310  [101, 14246, 1035, 16405, 15000, 11905, 1024, ...
# 1311  [101, 12832, 2291, 13792, 2951, 11020, 13684, ...
#
# [979 rows x 8 columns]

# %% [markdown]
# #### visualizations

# %%
# list for storing cleaned hashtags
cleaned_tags = []

# storing the tags
for cleaned_tag in tweets['Cleaned_Hashtags']:
    for tag in cleaned_tag:
        cleaned_tags.append(tag)
        
# finding the count of the tags
nWords = Counter(cleaned_tags)

# sorting the dictionary
sort_word = sorted(nWords.items(), key=lambda x:x[1], reverse=True)
sort_word = dict(sort_word)

# setting the bar plot
plt.rcParams.update({'font.size': 20})
words = list(sort_word.keys())[:20]
count = list(sort_word.values())[:20]
plt.figure(figsize=(25,20))
plt.bar(range(20), count, tick_label=words)
plt.tick_params(axis='x', direction='out', length=13, width=3, rotation=90)
plt.show()

# %%
# text for creating a word cloud
text = ' '.join(cleaned_tags)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'black').generate(text)

# Display the generated Word Cloud
plt.figure(figsize=(16,9))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# function to count the number of tags in each tweet post
def count(tag_list):
    return len(tag_list)

# creating a column showing the number of tags in corresponding post and changing dtype
tweets['numTags'] = tweets['Cleaned_Hashtags'].apply(lambda word: count(word))
tweets['numTags'] = tweets['numTags'].astype(str) 

# finding the count of the tags
nWords = Counter(tweets['numTags'])

# setting the bar plot
plt.rcParams.update({'font.size': 12})
words = list(nWords.keys())[:20]
l2 = [int(x) for x in words]
plt.figure(figsize=(8,6))
plt.bar(range(14), nWords.values(), tick_label=sorted(l2))
plt.title('Number of Tags in Twitter Posts', fontsize=16)
plt.xlabel('Tag Count')
plt.ylabel('Number of Tweets')
plt.tick_params(axis='x', direction='out', length=13, width=3, rotation=90)
plt.show()

# %% [markdown]
# #### creating preprocessed tweets excel file

# %%
tweets.drop(['numTags'], axis = 1)
tweets.to_excel('preprocessed_tweets.xlsx',index = False)
